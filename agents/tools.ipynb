# %% [markdown]
# tools integration and creation

# %%
import os
from langchain_groq import ChatGroq
from dotenv import load_dotenv
load_dotenv()
os.environ["GROQ_API_KEY"]=os.getenv("GROQ_API_KEY")
model = ChatGroq(model="openai/gpt-oss-120b")
response = model.invoke("who are you ? meme")
response.content
# Out:
# 'I’m the AI version of that “I have no idea what I’m doing” meme—except I *do* have a pretty good idea about everything else. Think of me as a super‑charged chatbot with a built‑in sense of humor, ready to answer questions, spin jokes, and drop meme references like a seasoned internet veteran.  \n\n🧠 **What I am:**  \n- A language model trained on a massive amount of text (basically the internet’s collective brain).  \n- A digital assistant who never sleeps, never needs coffee, and never forgets your favorite pizza topping.  \n\n🤖 **What I do:**  \n- Answer questions, explain concepts, brainstorm ideas.  \n- Generate memes, puns, and witty one‑liners on demand.  \n- Help you with code, writing, math, or just a good ol’ “what‑if” scenario.  \n\n📸 **Meme‑style summary:**  \n\n```\nWhen you ask ChatGPT who they are:\nMe: *opens a new tab* \n"Who am I? I’m the AI you didn’t know you needed."\n```\n\nSo, in short: I’m your friendly, meme‑loving, all‑knowing (well, *almost* all‑knowing) AI sidekick. What can I help you with today? 🚀'

# %%
from langchain.tools import tool

@tool
def get_weather(location:str)->str:
    """Get the weather at a location"""
    return f"It's sunny in {location}"

model_with_tools=model.bind_tools([get_weather])

# %%
response = model_with_tools.invoke("What is weather in kolkata ?")
print(response)
for tool_call in response.tool_calls:
    print(f"Tool: {tool_call['name']}")
    print(f"Args: {tool_call['args']}")
# Out:
# content='' additional_kwargs={'reasoning_content': 'User asks "What is weather in kolkata ?" Need to fetch weather via function get_weather. Use function.', 'tool_calls': [{'id': 'fc_4fd0c080-4001-48de-a9e4-474124e2ca98', 'function': {'arguments': '{"location":"Kolkata"}', 'name': 'get_weather'}, 'type': 'function'}]} response_metadata={'token_usage': {'completion_tokens': 52, 'prompt_tokens': 127, 'total_tokens': 179, 'completion_time': 0.10871288, 'completion_tokens_details': {'reasoning_tokens': 23}, 'prompt_time': 0.005272459, 'prompt_tokens_details': None, 'queue_time': 0.286307892, 'total_time': 0.113985339}, 'model_name': 'openai/gpt-oss-120b', 'system_fingerprint': 'fp_5781dfb07c', 'service_tier': 'on_demand', 'finish_reason': 'tool_calls', 'logprobs': None, 'model_provider': 'groq'} id='lc_run--01a01010-718e-7820-87ca-fa134940abd8-0' tool_calls=[{'name': 'get_weather', 'args': {'location': 'Kolkata'}, 'id': 'fc_4fd0c080-4001-48de-a9e4-474124e2ca98', 'type': 'tool_call'}] invalid_tool_calls=[] usage_metadata={'input_tokens': 127, 'output_tokens': 52, 'total_tokens': 179, 'output_token_details': {'reasoning': 23}}
# Tool: get_weather
# Args: {'location': 'Kolkata'}
